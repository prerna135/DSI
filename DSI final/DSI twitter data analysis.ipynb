# %%
import numpy as np
import pandas as pd
import re
import warnings
import sys
import os
from collections import defaultdict
import itertools
import json

#Visualisation
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

#nltk
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
from nltk import tokenize
import nltk
from nltk.corpus import stopwords
import operator
import string

#twitter api requests
import tweepy

# %matplotlib inline
# Out:
# /Users/prernakashyap/anaconda3/envs/gensim_env/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
f1 = "ira_tweets_csv_hashed.csv"
f2 = "iranian_tweets_csv_hashed.csv"

# %% [markdown]
# # About the data

# %% [markdown]
# * Justice Department charged 13 Russian nationals with interfering in American electoral and political processes. The defendants worked for a well-funded “troll factory” called the Internet Research Agency, which had 400 employees.
# * They ran a campaign to sow disinformation and discord into American politics via social media (mostly twitter).
# * Dataset includes information from 3,841 accounts believed to be connected to the Russian Internet Research Agency, and 770 accounts believed to originate in Iran. Includes all public, nondeleted tweets and media (e.g., images and videos) from accounts believed to be connected to state-backed information operations.
# * ~1.4 million people have now received a notification from Twitter for directly engaging during the election period with the 3,814 IRA-linked accounts identified (either by retweeting, quoting, replying to, mentioning, or liking those accounts or content created by those accounts) and actively following one of the identified IRA-linked accounts at the time those accounts were suspended.

# %%
ira = pd.read_csv(f1, error_bad_lines=False)
# iran = pd.read_csv(f2, error_bad_lines=False)
# Out:
# /Users/prernakashyap/anaconda3/envs/gensim_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # What info does the dataset contain?

# %%
ira.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9041308 entries, 0 to 9041307
# Data columns (total 31 columns):
# tweetid                     int64
# userid                      object
# user_display_name           object
# user_screen_name            object
# user_reported_location      object
# user_profile_description    object
# user_profile_url            object
# follower_count              int64
# following_count             int64
# account_creation_date       object
# account_language            object
# tweet_language              object
# tweet_text                  object
# tweet_time                  object
# tweet_client_name           object
# in_reply_to_tweetid         float64
# in_reply_to_userid          object
# quoted_tweet_tweetid        float64
# is_retweet                  bool
# retweet_userid              object
# retweet_tweetid             float64
# latitude                    float64
# longitude                   float64
# quote_count                 float64
# reply_count                 float64
# like_count                  float64
# retweet_count               float64
# hashtags                    object
# urls                        object
# user_mentions               object
# poll_choices                object
# dtypes: bool(1), float64(9), int64(3), object(18)
# memory usage: 2.0+ GB

# %% [markdown]
# # Analysis of accounts' popularity and activity

# %%
cols = ['follower_count', 'following_count', 'quote_count', 'reply_count', 'like_count', 'retweet_count']
ira[cols].describe()
# Out:
#        follower_count  following_count   quote_count   reply_count  \
# count    9.041308e+06     9.041308e+06  9.038635e+06  9.038635e+06
# mean     8.670202e+03     2.522468e+03  1.981891e-01  2.810441e-01
# std      2.214639e+04     5.028831e+03  1.307364e+01  7.408997e+00
# min      0.000000e+00     0.000000e+00  0.000000e+00  0.000000e+00
# 25%      3.460000e+02     2.840000e+02  0.000000e+00  0.000000e+00
# 50%      8.420000e+02     6.180000e+02  0.000000e+00  0.000000e+00
# 75%      4.486000e+03     2.014000e+03  0.000000e+00  0.000000e+00
# max      2.576380e+05     7.466400e+04  1.163300e+04  3.249000e+03
#
#          like_count  retweet_count
# count  9.038635e+06   9.038635e+06
# mean   4.002723e+00   3.457440e+00
# std    2.903125e+02   1.403270e+02
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    0.000000e+00   0.000000e+00
# max    3.258260e+05   1.236170e+05

# %% [markdown]
# From the above table we can draw the following conclusions:
# - The average number of followers the fake accounts had was around 8600.
# - The average number of people the fake accounts were following were around 2522.
# - Although interestingly, 75% of the accounts had no significant account activity like replying to tweets, liking tweets, retweeting, etc.
# - But 75% of the accounts had nearly 4500 followers and hence there outreach was large.

# %% [markdown]
# # Analysis on tweet locations

# %% [markdown]
# Below are the top 50 tweet locations. It's no surprise that USA is at the top, closely followed by Russian states.

# %%
ira['user_reported_location'].value_counts().nlargest(50)
# Out:
# USA                         774819
# Москва                      737454
# Санкт-Петербург             316650
# United States               302032
# Estados Unidos              285012
# Питер                       220464
# Россия                      184465
# Moscow                      146707
# Los Angeles, CA             127069
# Новосибирск                 124469
# МSK                         122025
# Санкт-Петербург, Россия     113974
# Чебоксары                   111773
# Новгород                    106124
# Омск                        100859
# Россия                       95841
# Chicago, IL                  90612
# New York, NY                 69659
# Atlanta                      65969
# СПБ                          64731
# Russia                       59693
# New York, USA                58856
# Москва, Россия               58601
# Kansas City, MO              52854
# Киев                         46806
# New Orleans, LA              46592
# Saint Petersburg, Russia     45760
# San Francisco, CA            45350
# СПб                          43847
# US                           42924
# SPB                          40685
# Washington, D.C.             38888
# Казань                       37005
# Нижний Новгород              34380
# Pittsburgh, PA               33809
# Екатеринбург                 33321
# Россия, Москва               32796
# Atlanta, GA                  31526
# Seattle, WA                  30237
# Москва (СССР - Россия)       30087
# Тула, Тульская область       29728
# NY                           29652
# StLouis                      29411
# St Louis, MO                 29324
# Мурманск                     28605
# Berlin, Deutschland          28451
# Baton Rouge, LA              27654
# Texas, USA                   27589
# City of Cleveland, USA       27458
# Philadelphia, PA             26920
# Name: user_reported_location, dtype: int64

# %% [markdown]
# # Most frequently occuring words in the tweets

# %%
ira_english = ira.loc[ira['tweet_language'] == 'en']
# ira_spanish = ira.loc[ira['tweet_language'] == 'es']

# %%
keyword_count = defaultdict(int)
stopwords = set(stopwords.words('english'))
stopwords.insert('rt')
stopwords.insert('rt')
stopwords.insert('rt')
whitelist = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')
all_tweets = ira_english[['tweet_text']].values
for tweet in all_tweets:
    for word in tweet[0].split():
        word = word.strip().lower()
        word = ''.join(filter(whitelist.__contains__, word))
        if word not in stopwords and word != '':
            keyword_count[word] += 1

# %% [markdown]
# Below is the list of the 100 most frequently occuring words in the tweets (barring stopwords in English like a, the, etc), sorted in the decreasing order of counts.

# %%
sorted(keyword_count.items(), key=operator.itemgetter(1), reverse=True)[:100]
# Out:
# [('rt', 1188742),
#  ('', 878395),
#  ('news', 273323),
#  ('trump', 157029),
#  ('sports', 104621),
#  ('new', 102660),
#  ('us', 92666),
#  ('dont', 88298),
#  ('people', 85228),
#  ('like', 84064),
#  ('politics', 83948),
#  ('man', 83442),
#  ('amp', 80070),
#  ('love', 78591),
#  ('im', 76677),
#  ('one', 72957),
#  ('police', 71340),
#  ('get', 70330),
#  ('world', 64247),
#  ('local', 60820),
#  ('obama', 59935),
#  ('time', 53993),
#  ('breaking', 53911),
#  ('make', 52786),
#  ('life', 52701),
#  ('know', 50646),
#  ('day', 48114),
#  ('video', 47259),
#  ('never', 47129),
#  ('says', 46439),
#  ('good', 46437),
#  ('black', 45813),
#  ('want', 45147),
#  ('go', 43943),
#  ('workout', 43845),
#  ('need', 40676),
#  ('president', 39866),
#  ('say', 39697),
#  ('cant', 39613),
#  ('back', 38142),
#  ('white', 38029),
#  ('https', 37972),
#  ('would', 37153),
#  ('business', 36458),
#  ('see', 36378),
#  ('chicago', 35732),
#  ('hillary', 35464),
#  ('first', 35378),
#  ('think', 35339),
#  ('right', 34789),
#  ('america', 34071),
#  ('health', 33881),
#  ('woman', 33349),
#  ('via', 33299),
#  ('still', 33249),
#  ('state', 32831),
#  ('youre', 32736),
#  ('got', 32103),
#  ('take', 32035),
#  ('house', 31467),
#  ('look', 31360),
#  ('clinton', 30786),
#  ('best', 30690),
#  ('texas', 30087),
#  ('great', 29832),
#  ('really', 29311),
#  ('thats', 29287),
#  ('way', 29197),
#  ('today', 29006),
#  ('foke', 28624),
#  ('going', 28619),
#  ('may', 28464),
#  ('live', 28215),
#  ('money', 28157),
#  ('could', 27895),
#  ('killed', 27533),
#  ('true', 26930),
#  ('stop', 26616),
#  ('watch', 26531),
#  ('years', 26409),
#  ('shooting', 26257),
#  ('realdonaldtrump', 26076),
#  ('trumps', 25431),
#  ('top', 25003),
#  ('things', 24867),
#  ('every', 24825),
#  ('even', 24769),
#  ('much', 24484),
#  ('media', 24427),
#  ('always', 24402),
#  ('let', 24218),
#  ('home', 23979),
#  ('two', 23400),
#  ('city', 23279),
#  ('u', 23068),
#  ('game', 22614),
#  ('help', 22604),
#  ('american', 22543),
#  ('better', 22481),
#  ('fire', 22472)]

# %% [markdown]
# # Most frequently occuring hashtags

# %%
hashtags = ira[['hashtags']].values
hashtag_count = defaultdict(int)
for entry in hashtags:
    if isinstance(entry[0], str):
        all_hashtags = entry[0].strip('[,]').split()
        for hashtag in all_hashtags:
            hashtag_count[hashtag.lower()] += 1

# %% [markdown]
# Below is a list of the 100 most frequently hashtags in all tweets, sorted in the decreasing order of counts.

# %%
sorted(hashtag_count.items(), key=operator.itemgetter(1), reverse=True)[:100]
# Out:
# [('news', 230977),
#  ('sports', 100987),
#  ('politics', 76107),
#  ('спб', 65508),
#  ('новости', 51670),
#  ('local', 31802),
#  ('world,', 28173),
#  ('русскийдух', 26936),
#  ('россия,', 26704),
#  ('local,', 24278),
#  ('провокациякиева', 22197),
#  ('киевсбилбоинг', 22099),
#  ('health', 21942),
#  ('киевскажиправду', 21807),
#  ('news,', 19881),
#  ('business', 19220),
#  ('maga', 19107),
#  ('breaking', 16675),
#  ('topnews', 16390),
#  ('chicago', 16104),
#  ('образроссии', 14765),
#  ('россия', 13918),
#  ('невскиеновости,', 13580),
#  ('newyork', 13378),
#  ('украина', 13326),
#  ('usa', 13128),
#  ('maga,', 12606),
#  ('новости,', 12372),
#  ('кино', 11541),
#  ('rap', 11406),
#  ('невскиеновости', 11297),
#  ('foke', 11173),
#  ('showbiz', 11132),
#  ('вернитекалифорнию', 11019),
#  ('авто', 10964),
#  ('спорт', 10806),
#  ('tech', 10779),
#  ('entertainment', 10575),
#  ('love', 10560),
#  ('fukushima2015', 10556),
#  ('blacklivesmatter', 10488),
#  ('quote,', 10120),
#  ('битваолигархов', 10023),
#  ('tcot,', 10023),
#  ('музыка', 9695),
#  ('спб,', 9514),
#  ('love,', 9292),
#  ('путин,', 8845),
#  ('украина,', 8750),
#  ('футбол', 8414),
#  ('sanjose', 8225),
#  ('crime', 8012),
#  ('business,', 7974),
#  ('pjnet', 7953),
#  ('chicago,', 7828),
#  ('американскаячума', 7805),
#  ('true', 7664),
#  ('зеленскийбеги', 7563),
#  ('секторбезгаза', 7538),
#  ('texas,', 7339),
#  ('blacklivesmatter,', 6982),
#  ('usa,', 6763),
#  ('fukushimaagain', 6687),
#  ('tcot', 6324),
#  ('пластмассовыйвек', 6322),
#  ('americafirst,', 6270),
#  ('true,', 6244),
#  ('рф,', 6195),
#  ('columbianchemicals', 5988),
#  ('money', 5921),
#  ('texas', 5917),
#  ('environment', 5839),
#  ('cleveland,', 5819),
#  ('trump,', 5569),
#  ('lavrovbestrong', 5519),
#  ('культура,', 5463),
#  ('games', 5457),
#  ('top', 5202),
#  ('fakenews,', 5120),
#  ('baseball', 5018),
#  ('sandiego', 5003),
#  ('america', 4984),
#  ('союзникироссии', 4926),
#  ('stoptank', 4889),
#  ('противсанкций', 4883),
#  ('stlouis', 4828),
#  ('эстафетасчастья', 4823),
#  ('breaking,', 4799),
#  ('pjnet,', 4662),
#  ('сша,', 4532),
#  ('политика,', 4387),
#  ('life', 4347),
#  ('политика', 4259),
#  ('крым,', 4222),
#  ('нетпровокациям', 4167),
#  ('imho', 4133),
#  ('ульяновск,', 4127),
#  ('кискаизвладика', 4121),
#  ('science', 4109),
#  ('turkeyaggressor', 4065)]

# %%
sorted_fc = ira_english.sort_values(['follower_count', 'following_count', 'quote_count', 'reply_count', 'like_count', 'retweet_count'], ascending=False)
sorted_fc = sorted_fc.groupby(['userid', 'user_display_name'])[['follower_count', 'following_count', 'quote_count', 'reply_count', 'like_count', 'retweet_count']].mean()
sorted_fc = sorted_fc.sort_values(['follower_count', 'following_count', 'quote_count', 'reply_count', 'like_count', 'retweet_count'], ascending=False)

# %% [markdown]
# - Below is a truncated list of the top 100 accounts sorted by account activity (which includes number of followers, number of replies, retweets and quotes and number of people followed by the account). The table includes the account ids which we will use to retrieve a list of followers using the twitter apis, the account username, the of followers, the number of people followed by the account, the average quote count, the average reply count, the average like count and the average tweet count.
# - It is evident that most of the top accounts are of Russian origin.

# %%
sorted_fc[:100]
# Out:
#                                          follower_count  following_count  \
# userid             user_display_name
# 2527472164         Вестник Москвы                257638              544
# 508761973          Вестник Петербурга            149672             1024
# 4224729994         Tennessee                     147767            74664
# 2808833544         Максим Дементьев              134805             2796
# 449689677          Рамзан Кадыров                123989               10
# 2648734430         Вестник Крыма                 106462              386
# 3676820373         Вестник Красноярска            85293              316
# 2665564544         Мюсли Лаврова                  84642             2575
# 2882331822         Jenna Abrams                   79152            22607
# 4272870988         Pamela Moore                   72121            42080
# 2752677905         New York City Today            66980            10500
# 2518710111         Вестник Новосибирска           60869             1246
# 2573726278         Вестник Казани                 59724              556
# 4218156466         ELEVEN GOP                     59279            30227
# 2533364158         Вестник Екатеринбург           59021             1252
# 2573933721         Вестник Н.Новгорода            58060              456
# 842368501528559616 Luisa Haynes                   57295            50746
# 4437233895         Crystal Johnson                56581            31117
# 3806028575         Вестник Тулы                   56526              467
# 3049228218         Вестник Луганска               54266              885
# 4355797094         Texas Lone Star                53999            49272
# 2351739462         Холодная Война 2.0             53175             5434
# 2526041465         Вестник Ростова                52288              283
# 2578890822         Вестник Уфы                    51831              409
# 1240007161         Замполит                       48912             1797
# 4508630900         John Davis                     47413            29429
# 3749844202         Вестник Волгограда             47296              728
# 2997392589         Вестник Донецка                45013              293
# 4332740714         Gunslinger Girl                44895            45382
# 2670490950         Брови Брежнева                 43504               88
# ...                                                 ...              ...
# 2944944427         Miami Today                    20718             8517
# 2944766250         Atlanta Online                 20345            13575
# 2494112058         San Jose Daily                 20135             9313
# 3978316814         BlackMatters                   20019            14112
# 900855837446504449 Tennessee                      19369              198
# 2753146444         Cleveland Online               19351             8207
# 2753211010         Phoenix Daily News             18574             7903
# 2591847731         Boston Today                   18560             7276
# 2577082467         Cincinnati Today               18361             5516
# 2620614029         Philadelphia Online            18011             8888
# 2262049316         ЖИВОЙ ДАЙДЖЕСТ                 16390             1200
# 2256210373         Викулова Татьяна               16220             1510
# 905514350684844036 Jemisha                        16006            12636
# 731456806082498560 Трибуна Онлайн                 15937             8788
# 3074013672         Oakland Online                 15884            13099
# 2570574680         РИА ФАН                        15753             6862
# 731123255457816577 Карточный Домик                14305             5445
# 2587474264         Minneapolis Online             13481             7724
# 2943515140         Screamy Monkey                 13358            13851
# 2951464703         Political Observer             13156             8253
# 3197151086         Material Evidence              13082             2933
# 748870305280647168 19:37                          13043             3092
# 3259934997         Выставка Вещдоки               12705             3073
# 2951539528         National Politics              12618             5184
# 3969530725         Being Patriotic                12421             9410
# 2951506251         Room Of Rumor                  12357             8501
# 2951556370         Special Affair                 12196             4948
# 4217244274         Yahaya Thinbu                  11766             6966
# 2525622731         тебе пиздец                    11378             1282
# 2687277211         Чистый Постмодерн              10963             2610
#
#                                          quote_count  reply_count  \
# userid             user_display_name
# 2527472164         Вестник Москвы           0.166667     0.166667
# 508761973          Вестник Петербурга       0.000000     0.055556
# 4224729994         Tennessee               49.569508    60.092487
# 2808833544         Максим Дементьев         0.006667     0.306667
# 449689677          Рамзан Кадыров           0.000000     2.847826
# 2648734430         Вестник Крыма            0.142857     0.714286
# 3676820373         Вестник Красноярска      0.000000     0.000000
# 2665564544         Мюсли Лаврова            0.000000     0.108696
# 2882331822         Jenna Abrams             2.254825     4.691032
# 4272870988         Pamela Moore            34.008049    40.015112
# 2752677905         New York City Today      0.042214     0.036602
# 2518710111         Вестник Новосибирска     0.000000     0.000000
# 2573726278         Вестник Казани           0.000000     0.000000
# 4218156466         ELEVEN GOP              13.055556    23.694444
# 2533364158         Вестник Екатеринбург     0.000000     0.000000
# 2573933721         Вестник Н.Новгорода      0.000000     0.000000
# 842368501528559616 Luisa Haynes            23.627201    50.846831
# 4437233895         Crystal Johnson         35.765408    10.047994
# 3806028575         Вестник Тулы             0.000000     0.000000
# 3049228218         Вестник Луганска         2.000000     3.000000
# 4355797094         Texas Lone Star         17.516624    24.718954
# 2351739462         Холодная Война 2.0       0.000000     0.313725
# 2526041465         Вестник Ростова          0.000000     0.000000
# 2578890822         Вестник Уфы              0.000000     0.000000
# 1240007161         Замполит                 0.000000     0.205882
# 4508630900         John Davis               3.650904     4.776313
# 3749844202         Вестник Волгограда       1.000000     0.000000
# 2997392589         Вестник Донецка          0.000000     0.000000
# 4332740714         Gunslinger Girl          5.497642     8.763103
# 2670490950         Брови Брежнева           0.000000     0.344828
# ...                                              ...          ...
# 2944944427         Miami Today              0.122352     0.037606
# 2944766250         Atlanta Online           0.073264     0.116186
# 2494112058         San Jose Daily           0.003966     0.019332
# 3978316814         BlackMatters             0.536368     0.853565
# 900855837446504449 Tennessee               66.977011    88.655172
# 2753146444         Cleveland Online         0.025906     0.027738
# 2753211010         Phoenix Daily News       0.025923     0.039992
# 2591847731         Boston Today             0.020562     0.036148
# 2577082467         Cincinnati Today         0.040580     0.021793
# 2620614029         Philadelphia Online      0.050813     0.067378
# 2262049316         ЖИВОЙ ДАЙДЖЕСТ           0.000000     0.000000
# 2256210373         Викулова Татьяна         0.000000     0.000000
# 905514350684844036 Jemisha                 31.362006     9.208569
# 731456806082498560 Трибуна Онлайн           0.750000     0.000000
# 3074013672         Oakland Online           0.008592     0.032719
# 2570574680         РИА ФАН                  0.000000     0.333333
# 731123255457816577 Карточный Домик          0.523810     0.190476
# 2587474264         Minneapolis Online       0.000000     0.010866
# 2943515140         Screamy Monkey           0.000152     0.003373
# 2951464703         Political Observer       0.275862     0.195402
# 3197151086         Material Evidence        0.013659     0.597412
# 748870305280647168 19:37                    0.000000     0.000000
# 3259934997         Выставка Вещдоки         0.000000     0.166667
# 2951539528         National Politics        0.402439     0.548780
# 3969530725         Being Patriotic          0.778924     1.302010
# 2951506251         Room Of Rumor            0.000096     0.002056
# 2951556370         Special Affair           0.117647     0.139706
# 4217244274         Yahaya Thinbu            2.462185     1.702614
# 2525622731         тебе пиздец              0.000000     0.068966
# 2687277211         Чистый Постмодерн        0.000000     0.300000
#
#                                           like_count  retweet_count
# userid             user_display_name
# 2527472164         Вестник Москвы           9.666667       4.500000
# 508761973          Вестник Петербурга       1.083333       2.000000
# 4224729994         Tennessee              666.755435     570.817792
# 2808833544         Максим Дементьев         2.146667       1.060000
# 449689677          Рамзан Кадыров           5.413043      13.695652
# 2648734430         Вестник Крыма            1.000000       0.285714
# 3676820373         Вестник Красноярска      1.000000       1.000000
# 2665564544         Мюсли Лаврова            0.239130       0.565217
# 2882331822         Jenna Abrams            30.377963      23.453089
# 4272870988         Pamela Moore           379.541721     364.332129
# 2752677905         New York City Today      0.459458       0.749002
# 2518710111         Вестник Новосибирска    11.000000       7.000000
# 2573726278         Вестник Казани           5.000000       0.000000
# 4218156466         ELEVEN GOP             382.935185     275.148148
# 2533364158         Вестник Екатеринбург     1.000000       1.000000
# 2573933721         Вестник Н.Новгорода      0.000000       4.000000
# 842368501528559616 Luisa Haynes          1374.801496     535.406690
# 4437233895         Crystal Johnson        733.710726     492.017965
# 3806028575         Вестник Тулы            88.000000      20.000000
# 3049228218         Вестник Луганска        13.000000      17.000000
# 4355797094         Texas Lone Star        177.589940     157.852515
# 2351739462         Холодная Война 2.0       0.776471       3.278431
# 2526041465         Вестник Ростова          1.000000       2.000000
# 2578890822         Вестник Уфы              1.000000       4.000000
# 1240007161         Замполит                 0.485294       1.823529
# 4508630900         John Davis              52.260296      48.214971
# 3749844202         Вестник Волгограда       2.000000       0.000000
# 2997392589         Вестник Донецка          0.000000       1.666667
# 4332740714         Gunslinger Girl         78.045860      69.459906
# 2670490950         Брови Брежнева           5.494253       3.275862
# ...                                              ...            ...
# 2944944427         Miami Today              0.631091       0.700874
# 2944766250         Atlanta Online           0.440321       0.824611
# 2494112058         San Jose Daily           0.277951       0.247803
# 3978316814         BlackMatters            13.361272      18.503131
# 900855837446504449 Tennessee              766.597701     603.218391
# 2753146444         Cleveland Online         0.300832       0.354842
# 2753211010         Phoenix Daily News       0.344073       0.393354
# 2591847731         Boston Today             0.371799       0.377799
# 2577082467         Cincinnati Today         0.403492       0.311290
# 2620614029         Philadelphia Online      0.308130       0.484858
# 2262049316         ЖИВОЙ ДАЙДЖЕСТ           0.000000       0.000000
# 2256210373         Викулова Татьяна         0.000000       0.000000
# 905514350684844036 Jemisha                957.450681     388.904683
# 731456806082498560 Трибуна Онлайн           7.250000       4.000000
# 3074013672         Oakland Online           0.267047       0.510586
# 2570574680         РИА ФАН                  0.000000       0.000000
# 731123255457816577 Карточный Домик         39.285714      13.190476
# 2587474264         Minneapolis Online       0.229778       0.208909
# 2943515140         Screamy Monkey           0.121118       0.077546
# 2951464703         Political Observer       1.195402       1.436782
# 3197151086         Material Evidence        6.076204      11.470884
# 748870305280647168 19:37                    0.268293       0.195122
# 3259934997         Выставка Вещдоки         0.083333       0.500000
# 2951539528         National Politics        3.646341       3.926829
# 3969530725         Being Patriotic         19.295492      22.366649
# 2951506251         Room Of Rumor            0.108270       0.044850
# 2951556370         Special Affair           0.897059       0.985294
# 4217244274         Yahaya Thinbu           46.068161      47.207283
# 2525622731         тебе пиздец              0.275862       0.068966
# 2687277211         Чистый Постмодерн        0.133333       0.100000
#
# [100 rows x 6 columns]

# %% [markdown]
# After checking all user ids in the dataset with the twitter ids it was evident that all these accounts have been suspended. So, it is impossible to get a list of followers for each account.

# %% [markdown]
# # Get list of all mentions and their counts

# %% [markdown]
# Doing this just for English right now as most of the mentions in the Russian tweets (for example) were mostly Russian newspapers and microblogging sites.

# %%
mentions = ira_english[['user_mentions']].values
mention_count = defaultdict(int)
for entry in mentions:
    if isinstance(entry[0], str):
        all_mentions = entry[0].strip('[,]').split()
        for mention in all_mentions:
            mention_count[mention] += 1
mention_count = sorted(mention_count.items(), key=operator.itemgetter(1), reverse=True)

# %% [markdown]
# There are 705382 unique mentions is all the English tweets in the dataset.

# %% [markdown]
# # Get a list of all users who were retweeted by IRA (English only)

# %%
retweeters = ira_english[['retweet_userid']].values
fake_acc = ira_english[['userid']].values
retweeter_count = defaultdict(int)
#retweeter_orig = defaultdict(set)
for i, entry in enumerate(retweeters):
    if isinstance(entry[0], str):
        all_retweeters = entry[0].strip('[,]').split()
        for retweeter in all_retweeters:
            retweeter_count[retweeter] += 1
            #retweeter_orig[retweeter].add(fake_acc[i][0])
retweeter_count = sorted(retweeter_count.items(), key=operator.itemgetter(1), reverse=True)

# %% [markdown]
# # Get all users who tweeted keywords (only English tweets)

# %%
keywords = ['criminals', 'felons', 'abortion', 'immigration', 'immigrants', 'illegal', 'aliens', 'guns', 'gun', 'violence', 'race', 'black', 'cops', 'pride', 'kings', 'queens', 'blackgirlmagic', 'blacklivesmatter']

# %%
whitelist = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')
keyword_retweeters = ira_english[['userid', 'tweet_text', 'retweet_userid', 'user_screen_name']].values
keyword_retweeter_count = defaultdict(int)
keyword_retweeter_tweets = defaultdict(list)
#keyword_retweeter_orig = defaultdict(list)
for entry in keyword_retweeters:
    tweet = entry[1].split()
    flag = False
    for word in tweet:
        word = ''.join(filter(whitelist.__contains__, word))
        if word in keywords:
            flag = True
    if isinstance(entry[2], str) and flag is True: # check for nan in retweet_useid column
        all_retweeters = entry[2].strip('[,]').split()
        for retweeter in all_retweeters:
            keyword_retweeter_count[retweeter] += 1
            keyword_retweeter_tweets[retweeter].append(entry[1])
            #keyword_retweeter_orig[retweeter].append([entry[0], entry[3]])
keyword_retweeter_count = sorted(keyword_retweeter_count.items(), key=operator.itemgetter(1), reverse=True)

# %% [markdown]
# There are 7331 unique tweeters of English tweets containing the above mentioned keywords in the dataset.

# %% [markdown]
# # Login to twitter API

# %%
twitter_creds = None
with open("twitter_credentials.json") as file:  
    twitter_creds = json.load(file)
auth = tweepy.auth.OAuthHandler(twitter_creds['consumer_key'], twitter_creds['consumer_secret'])
auth.set_access_token(twitter_creds['access_key'], twitter_creds['access_secret'])
api = tweepy.API(auth, wait_on_rate_limit=True)

if(api.verify_credentials):
    print ('Successfully logged in')
# Out:
# Successfully logged in

# %% [markdown]
# # Get list of users who mentioned fake IRA accounts

# %%
all_names = ira_english[['userid', 'user_screen_name', 'retweet_count']]
all_names = all_names.sort_values(by='retweet_count', ascending=False).values
filtered_names = defaultdict()
for entry in all_names:
    if entry[0].isdigit():
        filtered_names[entry[1]] = entry[2]
filtered_names = list(filtered_names.keys())

# %%
len(filtered_names)
# Out:
# 135

# %%
print(filtered_names)
# Out:
# ['Crystal1Johnson', 'KaniJJackson', 'JemiSHaaaZzz', 'wokeluisa', 'TrayneshaCole', 'BleepThePolice', 'BlackToLive', 'gloed_up', 'TEN_GOP', 'BlackNewsOutlet', 'LaChristie', 'Pamela_Moore13', 'JohnCopper16', 'Jenn_Abrams', 'USA_Gunslinger', 'SouthLoneStar', '10_gop', 'realTEN_GOP', 'ELEVEN_GOP', 'PamelaKealer13', 'Jeblary2016', 'Blk_Voice', 'TheFoundingSon', 'blackmattersus', 'WarfareWW', 'Baltimore0nline', 'patriototus', 'tpartynews', 'PigeonToday', 'MissouriNewsUS', 'todayinsyria', 'redlanews', 'DanaGeezus', 'MatEvidence', 'southlonestar2', 'MargoSavazh', 'rightnpr', 'Politweecs', 'DailyLosAngeles', 'Jihadist2ndWife', 'March_for_Trump', 'DetroitDailyNew', 'Patriot_Archive', 'DallasTopNews', 'Seattle_Post', 'GiselleEvns', 'AndyHashtagger', 'DickyIrwin', 'TodayNYCity', 'ItsTimeToSecede', 'NewOrleansON', 'DailySanFran', 'TodayMiami', 'byDrBre', 'WashingtOnline', 'LoraGreeen', 'KadirovRussia', 'HoustonTopNews', 'PhoenixDailyNew', 'ChrixMorgan', 'WhiteHouseCards', 'DominicValent', 'ComradZampolit', 'KansasDailyNews', 'OaklandOnline', 'coldwar20_ru', 'ChicagoDailyNew', 'KathieMrr', 'Booth_Prince', 'WorldOfHashtags', 'OnlineCleveland', 'erdollum', 'Atlanta_Online', 'DailySanDiego', 'Politkach', 'MinneapolisON', 'StLouisOnline', 'TodayBostonMA', 'AmandaVGreen', 'NovostiSPb', 'MaryMozhaiskaya', 'zubovnik', 'TodayPittsburgh', 'SanAntoTopNews', 'ScreamyMonkey', 'PhiladelphiaON', 'NatPolNews', 'TodayCincinnati', 'cascaseyp', 'MaxDementiev', 'OnlineMemphis', 'IlikeBIGbuttand', 'RoomOfRumor', 'polit_observer', 'ElPasoTopNews', 'VestnikTula', 'LavrovMuesli', 'NotRitaHart', 'DailySanJose', 'LuganskNovosti', 'boeing_is_back', 'SpecialAffair', 'bydrbre_', 'ruopentwit', 'NovostiMsk', 'NewspeakDaily', 'NovostiNsk', 'NovostiNN', 'TribunaOnline24', '4ever1937', 'MatEvidenceRU', 'DonetskNovosti', 'NovostiUf', 'NovostiDamask', 'NovostiRnD', 'russianallies', 'TebePizdec', 'NovostiCrimea', '1488reasons', 'Manzal_', 'chistpost', 'NovostiKrsnrsk', 'NovostiEkb', 'SpaceDept', 'Kotovamarys', 'riafanru', 'russilanrogov', 'AgitPolk', 'digestlj', 'NovostiKzn', 'sinigopajuby', 'SvetlankaZZzzz', 'sigermon', 'NovostiVolga', 'TrueNavalny']

# %%
whitelist = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')
keywords = ['criminals', 'felons', 'abortion', 'immigration', 'immigrants', 'illegal', 'aliens', 'guns', 'gun', 'violence', 'race', 'black', 'cops', 'pride', 'kings', 'queens', 'blackgirlmagic', 'blacklivesmatter']
locations = ['wisconsin', 'iowa', 'pennsylvania', 'florida', 'ohio', 'virginia', 'carolina', 'georgia']
filtered_user_dict = defaultdict(list)
#all_user_dict = defaultdict(list)
done = []
for name in filtered_names:
    for item in tweepy.Cursor(api.search, q='@'+name, count=100000).items():
        tweet = item.text.split()
        text_flag = False
        for word in tweet:
            word = ''.join(filter(whitelist.__contains__, word))
            if word in keywords:
                text_flag = True
        loc = item.author.location.split()
        loc_flag = False
        for entry in loc:
            entry = entry.lower().strip(',. ')
            if entry in locations:
                loc_flag = True
        if loc_flag is True:
            filtered_user_dict['user_id'].append(item.author.id_str)
            filtered_user_dict['user_screen_name'].append(item.author.name)
            filtered_user_dict['user_location'].append(item.author.location)
            filtered_user_dict['user_description'].append(item.author.description)
            filtered_user_dict['user_follower_count'].append(item.author.followers_count)
            filtered_user_dict['user_friend_count'].append(item.author.friends_count)
            filtered_user_dict['user_account_creation_date'].append(item.author.created_at)
            filtered_user_dict['user_tweet'].append(item.text)
            filtered_user_dict['fakebot_screen_name'].append(name)
    done.append(name)

# %%
filtered_user_dict_df = pd.DataFrame(filtered_user_dict)

# %%
filtered_user_dict_df
# Out:
#               user_id      user_screen_name   user_location  \
# 0          4180736069  Dmitch EX-GOP Consrv   Virginia, USA
# 1          4837060487  individual-1sFedcase  Wisconsin, USA
# 2  805636147649138689                   Joe       Ohio, USA
# 3  805636147649138689                   Joe       Ohio, USA
# 4  805636147649138689                   Joe       Ohio, USA
# 5  805636147649138689                   Joe       Ohio, USA
# 6           911242297          Sara Chirico   Virginia, USA
#
#                                     user_description  user_follower_count  \
# 0  Seek God 1st/Prolife Conserv #NeverTrump @Evan...                 2196
# 1  Daughter of a career Naval Flight Surgeon Sist...                 1185
# 2  Radical moderate, Dad,Buckeye,Vonnegut, Gonzo,...                 3330
# 3  Radical moderate, Dad,Buckeye,Vonnegut, Gonzo,...                 3330
# 4  Radical moderate, Dad,Buckeye,Vonnegut, Gonzo,...                 3330
# 5  Radical moderate, Dad,Buckeye,Vonnegut, Gonzo,...                 3330
# 6  wife, proud mom with 5 precious grandkids .......                  582
#
#    user_friend_count user_account_creation_date  \
# 0               4996        2015-11-13 18:52:58
# 1                538        2016-01-23 01:49:55
# 2               2024        2016-12-05 04:53:20
# 3               2024        2016-12-05 04:53:20
# 4               2024        2016-12-05 04:53:20
# 5               2024        2016-12-05 04:53:20
# 6               1454        2012-10-28 22:30:21
#
#                                           user_tweet fakebot_screen_name
# 0  RT @LouiseBagshawe: On the 12h day of Muellerm...             TEN_GOP
# 1  RT @SlickRockWeb: Did a quick search in our ar...      USA_Gunslinger
# 2  @LFredenhall @thespybrief @visionsurreal @GWil...     March_for_Trump
# 3  @GWillicker8 @thespybrief @visionsurreal @LFre...     March_for_Trump
# 4  @thespybrief @visionsurreal @LFredenhall @GWil...     March_for_Trump
# 5  @thespybrief @visionsurreal @LFredenhall @GWil...     March_for_Trump
# 6  RT @lovetogive2: @BenefitVBurden @mikefarb1 @R...     DetroitDailyNew

# %%
len(filtered_user_dict_df['fakebot_screen_name'].unique())
# Out:
# 15

# %%
filtered_user_dict_df.to_csv('mentions_all.csv')

# %% [markdown]
# # Use API to get user info

# %%
all_retweeters_df = pd.read_csv('./filtered_users.csv', error_bad_lines=False)
all_retweeters_ids = all_retweeters_df['user_id'].unique()
all_retweeters_ids = [str(entry) for entry in all_retweeters_ids]

# %%
len(all_retweeters_ids)
# Out:
# 211

# %%
filtered = []
for retweeter, cnt in keyword_retweeter_count:
    if retweeter not in done and retweeter not in all_retweeters_ids:
        try:
            user = api.get_user(retweeter)
            print(retweeter, user.screen_name, user.location)
            filtered.append(user)
            done.append(retweeter)
        except tweepy.TweepError as e:
            message = e.args[0][0]['message']
            if message == 'User has been suspended.' or message == 'User not found.':
                done.append(retweeter)

# %%
print(len(filtered), len(done)) #7246
# Out:
# 0 7246

# %%
# Filter users according to locations
locations = ['wisconsin', 'iowa', 'pennsylvania', 'florida', 'ohio', 'virginia', 'carolina', 'georgia']
retweeter_dict = defaultdict(list)
for r in filtered:
    loc = r.location.split()
    for entry in loc:
        entry = entry.lower().strip(',. ')
        if entry in locations:
            retweeter_dict[entry].append(tuple([r.id, r.screen_name, r.location]))

# %%
res = defaultdict(list)
for i in range(len(filtered)):
    for location in retweeter_dict.keys():
        flag = False
        for user in retweeter_dict[location]:
            if filtered[i].id == user[0]:
                flag = True
                break
        if flag == True:
            res['user_id'].append(filtered[i].id)
            res['user_screen_name'].append(filtered[i].screen_name)
            res['user_location'].append(location)
            res['user_description'].append(filtered[i].description)
            res['user_follower_count'].append(filtered[i].followers_count)
            res['user_friend_count'].append(filtered[i].friends_count)
            res['user_account_creation_date'].append(filtered[i].created_at)
            res['user_tweets'].append(keyword_retweeter_tweets[filtered[i].id_str])
            break

# %%
res_df = pd.DataFrame(res)

# %%
df_final = all_retweeters_df.append(res_df)
df_final = df_final.drop(df_final.columns[[0]], axis=1)

# %%
df_final
# Out:
#      user_follower_count  user_friend_count             user_id user_location  \
# 0                  43748              48175           905019768       florida
# 1                  44019              10578           237888723       florida
# 2                  53034               5972          2164876369       georgia
# 3                  34785              22914          2928451870      virginia
# 4                   2986                469          2880084329  pennsylvania
# 5                  86170               1038            27995424       florida
# 6                   2233               2370          1380313111          ohio
# 7                 164321             148658          3297022953      carolina
# 8                    726                736  796102909318598660      virginia
# 9                  13089              14168            16007872          iowa
# 10                  2877               2722           959403319          iowa
# 11                 20589              22574            49190063      virginia
# 12                  9462                681           109456108          ohio
# 13                   407               1093          2992218009      virginia
# 14                 59644              10550          4886114183       florida
# 15                 30747              16999            49800332      virginia
# 16                692995               1265            18587457      carolina
# 17                 37536               2536           254610836          iowa
# 18                  3335               3475            28659975       georgia
# 19                 40522              12199          2716100047       florida
# 20                 39000              17508           159563937  pennsylvania
# 21                258421             254573          1955132936      virginia
# 22                275019             276094          1065869268  pennsylvania
# 23                   356                463          4226317528      carolina
# 24                  4511               4015          2155451882      carolina
# 25                  1453                105           818194428       georgia
# 26                   211                459           262240091       florida
# 27                  5135               2873            16831827       georgia
# 28                 25710              16902          1548183698          ohio
# 29                  1190               1762            87510427       florida
# ..                   ...                ...                 ...           ...
# 181               212249               1750           110326494      carolina
# 182                 2392               2784            84523588      carolina
# 183                22797              14922           127486569       georgia
# 184                   90                 95  714912248985214976       florida
# 185               134456              52231  825518870421180416      carolina
# 186                12695                785            87371781  pennsylvania
# 187                28291               1933            17877451      carolina
# 188                44842              25831            59511805      carolina
# 189                 6893               7472          2869532963       florida
# 190                 1555               1159          1071841692      carolina
# 191                 1215               1892  730886312648183808       florida
# 192                 3616               3613          2186206505      virginia
# 193                 5626               2821  787113920297332736       florida
# 194                 6364               6783  758010931452350465       florida
# 195                 5477                497            69327809       georgia
# 196                  348                565          1494307680       florida
# 197                 7174               7886            42792991          ohio
# 198                 3629               2686           110681312          iowa
# 199               416104              22618             7429102      virginia
# 200                  177                650  736578912205967360       florida
# 201                  165                189          3518217197      carolina
# 202                  877                692           382847372      virginia
# 203                 4756               2577           885871045          ohio
# 204                 2064                918            29406461       florida
# 205                 4028               1578          2269619929     wisconsin
# 206                 1422               2519           104719487          iowa
# 207                 9353               9274           821403404       florida
# 208                  356                312           248819525      virginia
# 209                13145              13289  783830263885238272       georgia
# 210                48969              35140  783404381337157632      carolina
#
#     user_screen_name                                        user_tweets
# 0     Conservatexian  ['RT @Conservatexian: News post: "In Texas, un...
# 1       BIZPACReview  ['RT @BIZPACReview: ‘Best Senate race ever?’ S...
# 2     RepStevenSmith  ['RT @RepStevenSmith: So Trump ran on immigrat...
# 3    SenRichardBlack  ['RT @SenRichardBlack: SB1455, my bill to make...
# 4        50nsexy2014  ["RT @50nsexy2014: Neither democrats or republ...
# 5       johncardillo  ['RT @johncardillo: .@FoxNews, nice anti gun p...
# 6        joey_toledo  ["RT @joey_toledo: I'm from a small city in my...
# 7         kwilli1046  ['RT @kwilli1046: Marine Le Pen: "Mass immigra...
# 8     not_2dayplease  ['RT @wild14_u: #TheFirst100DaysToDoList  Supp...
# 9           cmdorsey  ['RT @cmdorsey: If we did everything LEFTISTS ...
# 10   Shane_Rodenbeck  ["RT @Shane_Rodenbeck: #ThingsYouShouldntAsk: ...
# 11     Amyloukingery  ['RT @Amyloukingery: Atheist Islamic apologist...
# 12          acluohio  ['RT @acluohio: Black children are children, d...
# 13   clydefarrisshow  ['RT @clydefarrisshow: @blackrepublican it wil...
# 14       soulphoodie  ['RT @soulphoodie: South Africa’s first black,...
# 15       MattMurph24  ['RT @MattMurph24: John Kasich signed a ban on...
# 16      MHarrisPerry  ['RT @MHarrisPerry: Join me on @BET Facebook l...
# 17     SiyandaWrites  ['RT @SiyandaWrites: Did you know in many "Ban...
# 18        ATLUGAGURL  ['RT @kelliegoodwin: PLS Vote and get rid of t...
# 19     FreedomChild3  ["RT @FreedomChild3: Jan Brewer: Donald Trump ...
# 20      davonmagwood  ['RT @davonmagwood: I just want President Obam...
# 21          varepall  ['RT @varepall: Democrats are off the charts r...
# 22   JohnFromCranber  ['RT @JohnFromCranber: Any illegal Protesting ...
# 23     uniformcode81  ['RT @uniformcode81: Kiss my black ass!   #POT...
# 24         kitten_nc  ['RT @kitten_nc: Thank you NYPD! Cops wreck pr...
# 25     DorothyABrown  ['RT @DorothyABrown: A radical idea to compens...
# 26   HernanLivesHere  ['RT @HernanLivesHere: #SuperheroPresidentialS...
# 27     emokidsloveme  ['RT @emokidsloveme: I finally got to this tra...
# 28            finy06  ["RT @finy06: It's a black problem......  @1Ta...
# 29   jessicaannbowma  ['RT @jessicaannbowma: So glad those cops were...
# ..               ...                                                ...
# 181      BreeNewsome  ['RT @BreeNewsome: LOL. When cops are turning ...
# 182         xavvypls  ["RT @xavvypls: ThankYouBernie: RT ThankYouBer...
# 183     mastadonarmy  ['RT @mastadonarmy: This guy organized violenc...
# 184        dj74hutch  ["RT @dj74hutch: @gloed_up Bernie has more of ...
# 185      RedTRaccoon  ["RT @RedTRaccoon: Trump stumbled on healthcar...
# 186   Imani_Barbarin  ['RT @Imani_Barbarin: black &amp;disabled is h...
# 187     MegKinnardAP  ['RT @MegKinnardAP: BREAKING: South Carolina c...
# 188        eddiern24  ['RT @eddiern: What the Hell did the Media thi...
# 189  ThatConservativ  ["RT @ThatConservativ: I'd like #illegal #Mexi...
# 190        JoYurcaba  ['RT @JoYurcaba: It has never worked. Never ha...
# 191    LaurieForReal  ['RT @LaurieForReal: What, exactly, did #Obama...
# 192    donna_dishman  ["RT @donna_dishman: @thinkprogress The USA ha...
# 193    JackBaileyUSA  ['RT @realjack_bailey: "America Needs Immigran...
# 194        Ir2much4u  ['RT @Ir2much4u: @larryelder @a95a911dd6ae864c...
# 195            mygpb  ['RT @mygpb: .@HenryLouisGates takes a persona...
# 196  SharanSelvaratn  ['RT @SharanSelvaratn: Its like killing black ...
# 197  RandomIgnorance  ['RT @RandomIgnorance: #IveHadItUpToHereWith P...
# 198       1861_again  ['RT @1861_again: Hey congress HANDSOFF my Hea...
# 199       MarkWarner  ['RT @MarkWarner: This is black and white: Tru...
# 200   gabriel_bogart  ['RT @gabriel_bogart: Disabled woman assaulted...
# 201     _dreamitbeit  ["RT @_dreamitbeit: I don't want my nephews to...
# 202       GuyDebored  ['RT @GuyDebored: @kaosum @TrayneshaCole This ...
# 203         BonBee81  ['RT @BonBee81: This psycho is illegal ..she w...
# 204     SezinKoehler  ['RT @SezinKoehler: This is common in abuse/do...
# 205   kristenhuff300  ['RT @kristenhuff300: I slammed the wine and a...
# 206  Stop_Govt_Waste  ['RT @Stop_Govt_Waste: Who looks at a new hire...
# 207       Firemdc780  ['RT @Firemdc780: Soul sista @HillaryClinton i...
# 208          SadGuy_  ['RT @SadGuy_: Niggas love God, hate women, lo...
# 209     deplorable_k  ['RT @deplorable_k: Deported. Came back. Getti...
# 210     S_Cooper0404  ['RT @S_Cooper0404: Muslims run thru the stree...
#
# [211 rows x 6 columns]

# %%
print(len(df_final['user_id'].unique()), len(df_final['user_screen_name'].unique()))
# Out:
# 211 211

# %%
df_final.to_csv('original_tweeters.csv', index=False)

# %%
all_mentions = []
for mention in mention_count:
    try:
        user = api.get_user(mention)
        print(user.screen_name)
        all_mentions.append(user)
    except:
        pass

# %%
with open("mentions.pkl", 'w') as f:
    pickle.dump(all_mentions, f)

# %%
def wordcloud(text):
    wordcloud = WordCloud(background_color="white", stopwords=stopwords, random_state = 42
                         ).generate(text)
    plt.figure( figsize=(20,10), facecolor='k')
    plt.imshow(wordcloud)
    plt.axis("off")
