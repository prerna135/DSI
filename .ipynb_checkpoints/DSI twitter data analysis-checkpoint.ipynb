# %%
import numpy as np
import pandas as pd
import re
import warnings
import sys
import os
from collections import defaultdict

#Visualisation
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

#nltk
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
from nltk import tokenize

# %matplotlib inline
# Out:
# /Users/prernakashyap/anaconda3/envs/gensim_env/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
dir1 = "Conversations_with_trolls";
dir2 = "russian-troll-tweets"

# %% [markdown]
# About the data:<br>
# -> Justice Department charged 13 Russian nationals with interfering in American electoral and political processes. The defendants worked for a well-funded “troll factory” called the Internet Research Agency, which had 400 employees. <br>
# -> They ran a campaign to sow disinformation and discord into American politics via social media (mostly twitter). <br>
# -> Obtained nearly 3 million tweets from accounts associated with the Internet Research Agency.<br>
# -> The data set includes 2,973,371 tweets from 2,848 Twitter handles.<br>
# -> It includes every tweet’s author, text and date; the author’s follower count and the number of accounts the author followed; an indication of whether the tweet was a retweet; language of the tweet; region of the tweet.<br>

# %%
all_handles = []
for fname in os.listdir(dir2):
    if fname.split('.')[-1] == "csv":
        fpath = os.path.join(dir2, fname)
        print(fpath)
        df = pd.read_csv(fpath, error_bad_lines=False)
        all_handles.append(df)
# Out:
# russian-troll-tweets/IRAhandle_tweets_4.csv
# russian-troll-tweets/IRAhandle_tweets_5.csv
# /Users/prernakashyap/anaconda3/envs/gensim_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,15,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# russian-troll-tweets/IRAhandle_tweets_7.csv
# russian-troll-tweets/IRAhandle_tweets_6.csv
# russian-troll-tweets/IRAhandle_tweets_2.csv
# russian-troll-tweets/IRAhandle_tweets_3.csv
# russian-troll-tweets/IRAhandle_tweets_1.csv
# russian-troll-tweets/IRAhandle_tweets_12.csv
# /Users/prernakashyap/anaconda3/envs/gensim_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# russian-troll-tweets/IRAhandle_tweets_13.csv
# ...

# %%
handle_info = []
for handle in all_handles:
    handle_info.append(handle[['following', 'followers', 'updates', 'retweet']].describe().to_dict())

all_info = defaultdict(lambda: defaultdict(list))
for handle in handle_info:
    for col in handle:
        for key in handle[col]:
            all_info[col][key].append(handle[col][key])

# %%
for col in all_info:
    print(col, '\n', pd.DataFrame(all_info[col]).describe())
# Out:
# following
#                 count         mean           std        min         25%  \
# count      13.000000    13.000000     13.000000  13.000000   13.000000
# mean   226631.307692  3231.163094   4390.926501  -0.230769  430.076923
# std     62697.090891  1869.985518   2775.564264   0.438529  238.076480
# min     20894.000000   582.201153    598.386683  -1.000000    2.000000
# 25%    239350.000000  2221.133067   2937.808532   0.000000  288.000000
# 50%    242958.000000  2683.056232   4065.588644   0.000000  412.000000
# 75%    250520.000000  4204.565089   5138.554058   0.000000  603.000000
# max    258051.000000  7601.823283  11679.457871   0.000000  795.000000
#
#                50%           75%           max
# count    13.000000     13.000000     13.000000
# mean   1775.000000   4566.076923  31084.692308
# std    1359.375163   2878.084475  18961.508873
# min       5.000000    875.000000   4145.000000
# 25%     939.000000   2284.000000  21843.000000
# ...

# %% [markdown]
# Observations:<br>
# -> Mean following of all accounts is 3231<br>
# -> Mean followers of all accounts is 4566<br>
# -> Mean number of “update actions” on the account that authored the tweet, including tweets, retweets and likes is ~10000<br>
# -> Tweets retweeted with a probability of ~0.5 (kind of inconclusive)<br>

# %%
all_tweets = [handle.split('https')[0] for handle in all_handles[0]['content'].tolist()]

# %%
def wordcloud(tweets):
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(background_color="white", stopwords=stopwords, random_state = 42
                         ).generate(tweets)
    plt.figure( figsize=(20,10), facecolor='k')
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.title("Word cloud for handle")

# %%
wordcloud(' '.join(all_tweets))

# %%
region_info = defaultdict(int)
for handle in all_handles:
    temp_dict = handle['region'].value_counts().to_dict()
    for item in temp_dict:
        region_info[item] += temp_dict[item]
region_info.pop(0, None)

# %%
import operator
sorted(region_info.items(), key=operator.itemgetter(1))
# Out:
# [('Austria', 1),
#  ('Switzerland', 1),
#  ('Denmark', 1),
#  ('Estonia', 1),
#  ('Serbia', 2),
#  ('Hong Kong', 3),
#  ('Latvia', 7),
#  ('Czech Republic', 7),
#  ('Turkey', 9),
#  ('Finland', 20),
#  ('India', 22),
#  ('Samoa', 32),
#  ('Mexico', 41),
#  ('Sweden', 52),
#  ('Saudi Arabia', 55),
#  ('Greece', 81),
#  ('Japan', 108),
#  ('Egypt', 232),
#  ('Spain', 515),
#  ('Iran, Islamic Republic of', 541),
#  ('Canada', 608),
#  ('France', 942),
#  ('Israel', 3604),
#  ('Afghanistan', 4888),
#  ('Malaysia', 4932),
#  ('Ukraine', 5765),
#  ('Iraq', 11117),
#  ('Italy', 13474),
#  ('United Kingdom', 18048),
#  ('Germany', 27178),
#  ('Belarus', 27802),
#  ('Russian Federation', 37589),
#  ('United Arab Emirates', 74675),
#  ('Azerbaijan', 96333),
#  ('Unknown', 561994),
#  ('United States', 2046709)]

# %% [markdown]
# Observations:<br>
# -> Large number of unknown regions. Mostly USA, though.<br>
# -> Quite a bit from the Russian federation.<br>

# %%
m = re.compile(r'@([^\s:]+)')
all_mentions = []
for tweet in all_tweets:
    mention = m.findall(tweet)
    if len(mention) > 0:
        all_mentions += mention

# %%
wordcloud(' '.join(all_mentions))
